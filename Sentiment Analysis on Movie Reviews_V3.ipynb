# %% [markdown]
# ## <center> Sentiment Analysis on Movie Reviews

# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

#Text Processing Packages
import re
import bs4
from bs4 import BeautifulSoup as bs

#NLP packages
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

#Model packages
import keras
from keras.models import Sequential
from keras.layers import Dense, GlobalMaxPooling1D, Bidirectional, LSTM, Embedding, Dropout
from keras.preprocessing.text import Tokenizer
from sklearn.metrics import accuracy_score, f1_score, roc_curve, roc_auc_score
import gensim
from gensim.models import Word2Vec

# %%
#Filter Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Read dataset
df_train = pd.read_csv('data/LabeledTrainData.tsv', delimiter='\t')
df_train.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
#Read test dataset
df_test = pd.read_csv('data/testData.tsv', delimiter='\t')
df_test.head()
# Out:
#          id                                             review
# 0  12311_10  Naturally in a film who's main themes are of m...
# 1    8348_2  This movie is a disaster within a disaster fil...
# 2    5828_4  All in all, this is a movie for kids. We saw i...
# 3    7186_2  Afraid of the Dark left me with the impression...
# 4   12128_7  A very accurate depiction of small time mob li...

# %%
df_train.shape, df_test.shape
# Out:
# ((25000, 3), (25000, 2))

# %%
#Let's backup both dataset
df_train_copy = df_train.copy()
df_test_copy = df_test.copy()

# %%
#Let's create a function to clean the data
def clean_text(text):
    #Steps - convert to lower, remove non-words, remove digits, remove single letters, remove spaces, remove stopwords
    text = bs(text, 'lxml').get_text()
    text = text.lower()
    text = re.sub('\W', ' ', text)
    text = re.sub('\d+', ' ', text)
    text = re.sub('\s+[a-z]\s+', ' ', text)
    text = re.sub('\s+', ' ', text)
    text = text.split(' ')
    text = [word for word in text if word not in stop_words]
    text = [WordNetLemmatizer().lemmatize(word) for word in text] #additional lemmatize the words
    text = ' '.join(text)
    return text

# %%
#Let's test the clean text function
temp = df_train.loc[0,'review']
temp
# Out:
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci's character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ's music.<br /><br />Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.<br /><br />Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ's bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i've gave this subject....hmmm well i don't know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."

# %%
clean_text(temp)
# Out:
# 'stuff going moment mj started listening music watching odd documentary watched wiz watched moonwalker maybe want get certain insight guy thought really cool eighty maybe make mind whether guilty innocent moonwalker part biography part feature film remember going see cinema originally released subtle message mj feeling towards press also obvious message drug bad kay visually impressive course michael jackson unless remotely like mj anyway going hate find boring may call mj egotist consenting making movie mj fan would say made fan true really nice actual feature film bit finally start minute excluding smooth criminal sequence joe pesci convincing psychopathic powerful drug lord want mj dead bad beyond mj overheard plan nah joe pesci character ranted wanted people know supplying drug etc dunno maybe hate mj music lot cool thing like mj turning car robot whole speed demon sequence also director must patience saint came filming kiddy bad sequence usually director hate working one kid let alone whole bunch performing complex dance scene bottom line movie people like mj one level another think people stay away try give wholesome message ironically mj bestest buddy movie girl michael jackson truly one talented people ever grace planet guilty well attention gave subject hmmm well know people different behind closed door know fact either extremely nice stupid guy one sickest liar hope latter '

# %%
#Lets process all the review in train
df_train['cleaned_review'] = df_train['review'].apply(lambda x: clean_text(x))

# %%
#Clean test dataset reviews
df_test['cleaned_review'] = df_test['review'].apply(lambda x: clean_text(x))
df_test['cleaned_review'].head()
# Out:
# 0    naturally film main theme mortality nostalgia ...
# 1    movie disaster within disaster film full great...
# 2    movie kid saw tonight child loved one point ki...
# 3    afraid dark left impression several different ...
# 4    accurate depiction small time mob life filmed ...
# Name: cleaned_review, dtype: object

# %% [markdown]
# ### Building Word Vector

# %%
#Preprocessing data to input into wordvector
corpus_train = [review.split(' ') for review in df_train['cleaned_review']]

# %%
WordVector = Word2Vec(sentences=corpus_train, min_count=4, size=300)
# embedding_vector_size = 256
# trigrams_model = Word2Vec(
#     sentences = trigrams[bigrams[all_reviews]],
#     size = embedding_vector_size,
#     min_count=3, window=5, workers=4)

# %%
#Let's check the vocabulary length
len(WordVector.wv.vocab)
# Out:
# 28627

# %%
#Let's check for similar words to see how word vec learnt
WordVector.wv.similar_by_word('good')
# Out:
# [('decent', 0.7355197668075562),
#  ('great', 0.6698894500732422),
#  ('alright', 0.6664667129516602),
#  ('bad', 0.6496267318725586),
#  ('okay', 0.643833339214325),
#  ('nice', 0.630272626876831),
#  ('ok', 0.6258782744407654),
#  ('fine', 0.6013451218605042),
#  ('cool', 0.6003857851028442),
#  ('awesome', 0.5974669456481934)]

# %%
WordVector.wv.similarity('film', 'movie')
# Out:
# 0.7643779

# %% [markdown]
# ### Building Neural Network Model

# %%
model = Sequential()

model.add(Embedding(input_dim = WordVector.wv.vectors.shape[0], output_dim = WordVector.wv.vectors.shape[1], 
                    weights=[WordVector.wv.vectors]))

model.add(Bidirectional(LSTM(32, recurrent_dropout=0.1, return_sequences=True)))

model.add(GlobalMaxPooling1D())

model.add(Dense(32, activation='relu'))

model.add(Dropout(rate = 0.2))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 300)         8588100
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, None, 64)          85248
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 8,675,461
# Trainable params: 8,675,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the model
model.fit()

# %% [markdown]
# ## Phrases

# %%
from gensim.models import Phrases

# %%
bigrams = Phrases(corpus_train)

# %%
x = bigrams.vocab
len(x)
# Out:
# 1740753

# %%
x
# Out:
# defaultdict(int,
#             {b'stuff': 1181,
#              b'going': 4146,
#              b'stuff_going': 6,
#              b'moment': 2775,
#              b'going_moment': 2,
#              b'mj': 35,
#              b'moment_mj': 2,
#              b'started': 963,
#              b'mj_started': 1,
#              b'listening': 189,
#              b'started_listening': 1,
#              b'music': 3061,
#              b'listening_music': 7,
#              b'watching': 4605,
#              b'music_watching': 1,
#              b'odd': 582,
#              b'watching_odd': 2,
#              b'documentary': 1074,
#              b'odd_documentary': 1,
#              b'watched': 2236,
#              b'documentary_watched': 3,
#              b'wiz': 11,
#              b'watched_wiz': 1,
#              b'wiz_watched': 1,
#              b'moonwalker': 24,
#              b'watched_moonwalker': 1,
#              b'maybe': 2340,
#              b'moonwalker_maybe': 1,
#              b'want': 4989,
#              b'maybe_want': 9,
#              b'get': 12513,
#              b'want_get': 108,
#              b'certain': 764,
#              b'get_certain': 3,
#              b'insight': 250,
#              b'certain_insight': 1,
#              b'guy': 4339,
#              b'insight_guy': 1,
#              b'thought': 3656,
#              b'guy_thought': 3,
#              b'really': 11735,
#              b'thought_really': 23,
#              b'cool': 971,
#              b'really_cool': 69,
#              b'eighty': 127,
#              b'cool_eighty': 1,
#              b'eighty_maybe': 1,
#              b'make': 12225,
#              b'maybe_make': 10,
#              b'mind': 2180,
#              b'make_mind': 46,
#              b'whether': 856,
#              b'mind_whether': 10,
#              b'guilty': 198,
#              b'whether_guilty': 1,
#              b'innocent': 434,
#              b'guilty_innocent': 3,
#              b'innocent_moonwalker': 1,
#              b'part': 5233,
#              b'moonwalker_part': 1,
#              b'biography': 99,
#              b'part_biography': 1,
#              b'biography_part': 1,
#              b'feature': 1434,
#              b'part_feature': 2,
#              b'film': 47032,
#              b'feature_film': 159,
#              b'remember': 1702,
#              b'film_remember': 27,
#              b'remember_going': 2,
#              b'see': 12012,
#              b'going_see': 60,
#              b'cinema': 1553,
#              b'see_cinema': 14,
#              b'originally': 290,
#              b'cinema_originally': 1,
#              b'released': 986,
#              b'originally_released': 16,
#              b'subtle': 434,
#              b'released_subtle': 1,
#              b'message': 960,
#              b'subtle_message': 6,
#              b'message_mj': 1,
#              b'feeling': 1540,
#              b'mj_feeling': 1,
#              b'towards': 637,
#              b'feeling_towards': 18,
#              b'press': 134,
#              b'towards_press': 1,
#              b'also': 9156,
#              b'press_also': 2,
#              b'obvious': 1066,
#              b'also_obvious': 5,
#              b'obvious_message': 3,
#              b'drug': 728,
#              b'message_drug': 2,
#              b'bad': 9302,
#              b'drug_bad': 5,
#              b'kay': 90,
#              b'bad_kay': 1,
#              b'visually': 259,
#              b'kay_visually': 1,
#              b'impressive': 500,
#              b'visually_impressive': 3,
#              b'course': 2517,
#              b'impressive_course': 2,
#              b'michael': 1370,
#              b'course_michael': 5,
#              b'jackson': 346,
#              b'michael_jackson': 80,
#              b'unless': 675,
#              b'jackson_unless': 1,
#              b'remotely': 189,
#              b'unless_remotely': 1,
#              b'like': 20740,
#              b'remotely_like': 4,
#              b'like_mj': 4,
#              b'anyway': 1117,
#              b'mj_anyway': 1,
#              b'anyway_going': 3,
#              b'hate': 893,
#              b'going_hate': 5,
#              b'find': 5079,
#              b'hate_find': 1,
#              b'boring': 1809,
#              b'find_boring': 7,
#              b'may': 3392,
#              b'boring_may': 2,
#              b'call': 1183,
#              b'may_call': 7,
#              b'call_mj': 1,
#              b'egotist': 5,
#              b'mj_egotist': 1,
#              b'consenting': 5,
#              b'egotist_consenting': 1,
#              b'making': 2978,
#              b'consenting_making': 1,
#              b'movie': 51694,
#              b'making_movie': 193,
#              b'movie_mj': 1,
#              b'fan': 3331,
#              b'mj_fan': 3,
#              b'would': 12436,
#              b'fan_would': 36,
#              b'say': 6505,
#              b'would_say': 244,
#              b'made': 8362,
#              b'say_made': 12,
#              b'made_fan': 6,
#              b'true': 2333,
#              b'fan_true': 8,
#              b'true_really': 10,
#              b'nice': 2012,
#              b'really_nice': 48,
#              b'actual': 793,
#              b'nice_actual': 1,
#              b'actual_feature': 3,
#              b'bit': 3349,
#              b'film_bit': 61,
#              b'finally': 1536,
#              b'bit_finally': 2,
#              b'start': 2919,
#              b'finally_start': 8,
#              b'minute': 3741,
#              b'start_minute': 3,
#              b'excluding': 14,
#              b'minute_excluding': 1,
#              b'smooth': 129,
#              b'excluding_smooth': 1,
#              b'criminal': 499,
#              b'smooth_criminal': 23,
#              b'sequence': 1603,
#              b'criminal_sequence': 3,
#              b'joe': 690,
#              b'sequence_joe': 2,
#              b'pesci': 29,
#              b'joe_pesci': 24,
#              b'convincing': 538,
#              b'pesci_convincing': 1,
#              b'psychopathic': 23,
#              b'convincing_psychopathic': 1,
#              b'powerful': 620,
#              b'psychopathic_powerful': 1,
#              b'powerful_drug': 2,
#              b'lord': 373,
#              b'drug_lord': 24,
#              b'lord_want': 1,
#              b'want_mj': 1,
#              b'dead': 1881,
#              b'mj_dead': 1,
#              b'dead_bad': 6,
#              b'beyond': 866,
#              b'bad_beyond': 5,
#              b'beyond_mj': 1,
#              b'overheard': 7,
#              b'mj_overheard': 1,
#              b'plan': 623,
#              b'overheard_plan': 1,
#              b'nah': 18,
#              b'plan_nah': 1,
#              b'nah_joe': 1,
#              b'character': 14177,
#              b'pesci_character': 2,
#              b'ranted': 4,
#              b'character_ranted': 1,
#              b'wanted': 1352,
#              b'ranted_wanted': 1,
#              b'people': 9385,
#              b'wanted_people': 3,
#              b'know': 7067,
#              b'people_know': 115,
#              b'supplying': 10,
#              b'know_supplying': 1,
#              b'supplying_drug': 1,
#              b'etc': 1212,
#              b'drug_etc': 3,
#              b'dunno': 24,
#              b'etc_dunno': 1,
#              b'dunno_maybe': 1,
#              b'maybe_hate': 5,
#              b'hate_mj': 1,
#              b'mj_music': 1,
#              b'lot': 4778,
#              b'music_lot': 10,
#              b'lot_cool': 5,
#              b'thing': 8210,
#              b'cool_thing': 7,
#              b'thing_like': 235,
#              b'turning': 345,
#              b'mj_turning': 1,
#              b'car': 1504,
#              b'turning_car': 1,
#              b'robot': 329,
#              b'car_robot': 3,
#              b'whole': 3079,
#              b'robot_whole': 1,
#              b'speed': 266,
#              b'whole_speed': 1,
#              b'demon': 375,
#              b'speed_demon': 7,
#              b'demon_sequence': 1,
#              b'sequence_also': 11,
#              b'director': 5119,
#              b'also_director': 18,
#              b'must': 3250,
#              b'director_must': 13,
#              b'patience': 81,
#              b'must_patience': 1,
#              b'saint': 117,
#              b'patience_saint': 1,
#              b'came': 1673,
#              b'saint_came': 1,
#              b'filming': 393,
#              b'came_filming': 1,
#              b'kiddy': 28,
#              b'filming_kiddy': 1,
#              b'kiddy_bad': 1,
#              b'bad_sequence': 3,
#              b'usually': 981,
#              b'sequence_usually': 2,
#              b'usually_director': 3,
#              b'director_hate': 2,
#              b'working': 817,
#              b'hate_working': 1,
#              b'one': 27741,
#              b'working_one': 5,
#              b'kid': 3042,
#              b'one_kid': 24,
#              b'let': 2675,
#              b'kid_let': 9,
#              b'alone': 1061,
#              b'let_alone': 126,
#              b'alone_whole': 1,
#              b'bunch': 817,
#              b'whole_bunch': 28,
#              b'performing': 131,
#              b'bunch_performing': 1,
#              b'complex': 429,
#              b'performing_complex': 1,
#              b'dance': 847,
#              b'complex_dance': 1,
#              b'scene': 10585,
#              b'dance_scene': 36,
#              b'bottom': 433,
#              b'scene_bottom': 3,
#              b'line': 3419,
#              b'bottom_line': 145,
#              b'line_movie': 85,
#              b'movie_people': 123,
#              b'people_like': 255,
#              b'mj_one': 1,
#              b'level': 1198,
#              b'one_level': 22,
#              b'another': 4325,
#              b'level_another': 3,
#              b'think': 7732,
#              b'another_think': 4,
#              b'think_people': 81,
#              b'stay': 969,
#              b'people_stay': 10,
#              b'away': 2774,
#              b'stay_away': 158,
#              b'try': 3109,
#              b'away_try': 3,
#              b'give': 4952,
#              b'try_give': 23,
#              b'wholesome': 45,
#              b'give_wholesome': 1,
#              b'wholesome_message': 1,
#              b'ironically': 123,
#              b'message_ironically': 1,
#              b'ironically_mj': 1,
#              b'bestest': 2,
#              b'mj_bestest': 1,
#              b'buddy': 367,
#              b'bestest_buddy': 1,
#              b'buddy_movie': 11,
#              b'girl': 4064,
#              b'movie_girl': 26,
#              b'girl_michael': 2,
#              b'truly': 1743,
#              b'jackson_truly': 1,
#              b'truly_one': 53,
#              b'talented': 586,
#              b'one_talented': 13,
#              b'talented_people': 19,
#              b'ever': 5995,
#              b'people_ever': 22,
#              b'grace': 358,
#              b'ever_grace': 15,
#              b'planet': 534,
#              b'grace_planet': 1,
#              b'planet_guilty': 1,
#              b'well': 10782,
#              b'guilty_well': 1,
#              b'attention': 929,
#              b'well_attention': 1,
#              b'gave': 1216,
#              b'attention_gave': 2,
#              b'subject': 816,
#              b'gave_subject': 1,
#              b'hmmm': 50,
#              b'subject_hmmm': 1,
#              b'hmmm_well': 3,
#              b'well_know': 66,
#              b'know_people': 107,
#              b'different': 2385,
#              b'people_different': 14,
#              b'behind': 1280,
#              b'different_behind': 1,
#              b'closed': 92,
#              b'behind_closed': 3,
#              b'door': 557,
#              b'closed_door': 9,
#              b'door_know': 2,
#              b'fact': 3747,
#              b'know_fact': 24,
#              b'either': 1866,
#              b'fact_either': 2,
#              b'extremely': 1068,
#              b'either_extremely': 4,
#              b'extremely_nice': 2,
#              b'stupid': 1701,
#              b'nice_stupid': 1,
#              b'stupid_guy': 2,
#              b'guy_one': 28,
#              b'sickest': 10,
#              b'one_sickest': 2,
#              b'liar': 48,
#              b'sickest_liar': 1,
#              b'hope': 1720,
#              b'liar_hope': 1,
#              b'latter': 362,
#              b'hope_latter': 2,
#              b'': 25361,
#              b'latter_': 4,
#              b'classic': 2061,
#              b'_classic': 4,
#              b'war': 2382,
#              b'classic_war': 1,
#              b'world': 3978,
#              b'war_world': 46,
#              b'timothy': 118,
#              b'world_timothy': 2,
#              b'hines': 48,
#              b'timothy_hines': 12,
#              b'entertaining': 1442,
#              b'hines_entertaining': 1,
#              b'entertaining_film': 69,
#              b'obviously': 1162,
#              b'film_obviously': 57,
#              b'go': 7599,
#              b'obviously_go': 2,
#              b'great': 9087,
#              b'go_great': 29,
#              b'effort': 1046,
#              b'great_effort': 7,
#              b'length': 361,
#              b'effort_length': 1,
#              b'faithfully': 22,
#              b'length_faithfully': 1,
#              b'recreate': 35,
#              b'faithfully_recreate': 1,
#              b'g': 222,
#              b'recreate_g': 1,
#              b'g_well': 26,
#              b'well_classic': 13,
#              b'book': 2926,
#              b'classic_book': 6,
#              b'mr': 1708,
#              b'book_mr': 3,
#              b'mr_hines': 6,
#              b'succeeds': 167,
#              b'hines_succeeds': 1,
#              b'succeeds_watched': 1,
#              b'watched_film': 143,
#              b'appreciated': 196,
#              b'film_appreciated': 7,
#              b'appreciated_fact': 5,
#              b'standard': 803,
#              b'fact_standard': 2,
#              b'predictable': 854,
#              b'standard_predictable': 1,
#              b'hollywood': 1911,
#              b'predictable_hollywood': 5,
#              b'fare': 226,
#              b'hollywood_fare': 13,
#              b'come': 5673,
#              b'fare_come': 1,
#              b'every': 3978,
#              b'come_every': 14,
#              b'year': 6878,
#              b'every_year': 57,
#              b'year_g': 1,
#              b'spielberg': 154,
#              b'g_spielberg': 1,
#              b'version': 2410,
#              b'spielberg_version': 5,
#              b'tom': 783,
#              b'version_tom': 6,
#              b'cruise': 134,
#              b'tom_cruise': 60,
#              b'slightest': 122,
#              b'cruise_slightest': 1,
#              b'resemblance': 115,
#              b'slightest_resemblance': 3,
#              b'resemblance_book': 3,
#              b'book_obviously': 4,
#              b'everyone': 2222,
#              b'obviously_everyone': 2,
#              b'look': 6558,
#              b'everyone_look': 14,
#              b'look_different': 16,
#              b'different_thing': 18,
#              b'thing_movie': 308,
#              b'envision': 9,
#              b'movie_envision': 1,
#              b'amateur': 246,
#              b'envision_amateur': 1,
#              b'critic': 522,
#              b'amateur_critic': 1,
#              b'critic_look': 1,
#              b'criticize': 51,
#              b'look_criticize': 1,
#              b'everything': 2320,
#              b'criticize_everything': 1,
#              b'others': 1595,
#              b'everything_others': 2,
#              b'rate': 704,
#              b'others_rate': 1,
#              b'rate_movie': 73,
#              b'important': 931,
#              b'movie_important': 15,
#              b'base': 198,
#              b'important_base': 1,
#              b'base_like': 3,
#              b'entertained': 237,
#              b'like_entertained': 2,
#              b'entertained_people': 4,
#              b'never': 6484,
#              b'people_never': 36,
#              b'agree': 572,
#              b'never_agree': 1,
#              b'agree_critic': 2,
#              b'enjoyed': 1245,
#              b'critic_enjoyed': 1,
#              b'enjoyed_effort': 1,
#              b'effort_mr': 2,
#              b'put': 2760,
#              b'hines_put': 1,
#              b'faithful': 178,
#              b'put_faithful': 1,
#              b'faithful_g': 1,
#              b'novel': 1126,
#              b'classic_novel': 24,
#              b'found': 2576,
#              b'novel_found': 2,
#              b'found_entertaining': 13,
#              b'entertaining_made': 4,
#              b'easy': 802,
#              b'made_easy': 1,
#              b'overlook': 92,
#              b'easy_overlook': 4,
#              b'overlook_critic': 1,
#              b'perceive': 34,
#              b'critic_perceive': 1,
#              b'shortcoming': 77,
#              b'perceive_shortcoming': 1,
#              b'shortcoming_': 4,
#              b'film_start': 122,
#              b'manager': 168,
#              b'start_manager': 1,
#              b'nicholas': 92,
#              b'manager_nicholas': 1,
#              b'bell': 136,
#              b'nicholas_bell': 2,
#              b'giving': 840,
#              b'bell_giving': 1,
#              b'welcome': 226,
#              b'giving_welcome': 1,
#              b'investor': 14,
#              b'welcome_investor': 1,
#              b'robert': 1093,
#              b'investor_robert': 1,
#              b'carradine': 94,
#              b'robert_carradine': 7,
#              b'primal': 32,
#              b'carradine_primal': 1,
#              b'park': 411,
#              b'primal_park': 6,
#              b'secret': 724,
#              b'park_secret': 1,
#              b'project': 623,
#              b'secret_project': 1,
#              b'mutating': 2,
#              b'project_mutating': 1,
#              b'mutating_primal': 1,
#              b'animal': 752,
#              b'primal_animal': 1,
#              b'using': 801,
#              b'animal_using': 1,
#              b'fossilized': 1,
#              b'using_fossilized': 1,
#              b'dna': 24,
#              b'fossilized_dna': 1,
#              b'dna_like': 1,
#              b'jurassik': 2,
#              b'like_jurassik': 1,
#              b'jurassik_park': 2,
#              b'scientist': 477,
#              b'park_scientist': 1,
#              b'resurrect': 24,
#              b'scientist_resurrect': 1,
#              b'resurrect_one': 1,
#              b'nature': 723,
#              b'one_nature': 3,
#              b'fearsome': 10,
#              b'nature_fearsome': 2,
#              b'predator': 72,
#              b'fearsome_predator': 2,
#              b'sabretooth': 31,
#              b'predator_sabretooth': 1,
#              b'tiger': 109,
#              b'sabretooth_tiger': 5,
#              b'smilodon': 3,
#              b'tiger_smilodon': 1,
#              b'scientific': 119,
#              b'smilodon_scientific': 1,
#              b'ambition': 118,
#              b'scientific_ambition': 1,
#              b'turn': 2610,
#              b'ambition_turn': 1,
#              b'deadly': 201,
#              b'turn_deadly': 3,
#              b'however': 3537,
#              b'deadly_however': 1,
#              b'high': 2174,
#              b'however_high': 3,
#              b'voltage': 9,
#              b'high_voltage': 6,
#              b'fence': 50,
#              b'voltage_fence': 1,
#              b'opened': 155,
#              b'fence_opened': 1,
#              b'creature': 554,
#              b'opened_creature': 1,
#              b'escape': 701,
#              b'creature_escape': 2,
#              b'begin': 1473,
#              b'escape_begin': 2,
#              b'savagely': 17,
#              b'begin_savagely': 1,
#              b'stalking': 62,
#              b'savagely_stalking': 2,
#              b'prey': 82,
#              b'stalking_prey': 3,
#              b'human': 1915,
#              b'prey_human': 1,
#              b'visitor': 77,
#              b'human_visitor': 1,
#              b'tourist': 91,
#              b'visitor_tourist': 1,
#              b'tourist_scientific': 1,
#              b'meanwhile': 249,
#              b'scientific_meanwhile': 1,
#              b'youngster': 57,
#              b'meanwhile_youngster': 1,
#              b'enter': 196,
#              b'youngster_enter': 1,
#              b'restricted': 27,
#              b'enter_restricted': 1,
#              b'area': 453,
#              b'restricted_area': 1,
#              b'security': 195,
#              b'area_security': 1,
#              b'center': 323,
#              b'security_center': 1,
#              b'attacked': 158,
#              b'center_attacked': 1,
#              b'pack': 210,
#              b'attacked_pack': 1,
#              b'large': 556,
#              b'pack_large': 1,
#              b'pre': 309,
#              b'large_pre': 1,
#              b'historical': 407,
#              b'pre_historical': 1,
#              b'historical_animal': 1,
#              b'deadlier': 2,
#              b'animal_deadlier': 1,
#              b'bigger': 268,
#              b'deadlier_bigger': 1,
#              b'addition': 371,
#              b'bigger_addition': 1,
#              b'addition_security': 1,
#              b'agent': 455,
#              b'security_agent': 1,
#              b'stacy': 21,
#              b'agent_stacy': 1,
#              b'haiduk': 2,
#              b'stacy_haiduk': 2,
#              b'mate': 183,
#              b'haiduk_mate': 1,
#              b'brian': 352,
#              b'mate_brian': 1,
#              b'wimmer': 2,
#              b'brian_wimmer': 2,
#              b'fight': 1433,
#              b'wimmer_fight': 1,
#              b'hardly': 613,
#              b'fight_hardly': 1,
#              b'carnivorous': 7,
#              b'hardly_carnivorous': 1,
#              b'smilodons': 1,
#              b'carnivorous_smilodons': 1,
#              b'sabretooths': 7,
#              b'smilodons_sabretooths': 1,
#              b'sabretooths_course': 1,
#              b'real': 4736,
#              b'course_real': 8,
#              b'star': 3782,
#              b'real_star': 44,
#              b'star_star': 9,
#              b'astounding': 59,
#              b'star_astounding': 1,
#              b'terrifyingly': 13,
#              b'astounding_terrifyingly': 1,
#              b'though': 4566,
#              b'terrifyingly_though': 1,
#              b'though_convincing': 5,
#              b'giant': 440,
#              b'convincing_giant': 1,
#              b'giant_animal': 3,
#              b'animal_savagely': 1,
#              b'group': 1142,
#              b'prey_group': 1,
#              b'run': 1731,
#              b'group_run': 2,
#              b'afoul': 13,
#              b'run_afoul': 13,
#              b'afoul_fight': 1,
#              b'fight_one': 28,
#              b'furthermore': 106,
#              b'predator_furthermore': 1,
#              b'third': 776,
#              b'furthermore_third': 1,
#              b'third_sabretooth': 1,
#              b'dangerous': 291,
#              b'sabretooth_dangerous': 1,
#              b'slow': 1131,
#              b'dangerous_slow': 1,
#              b'stalk': 66,
#              b'slow_stalk': 1,
#              b'victim': 793,
#              b'stalk_victim': 3,
#              b'victim_movie': 9,
#              b'delivers': 356,
#              b'movie_delivers': 17,
#              b'good': 15197,
#              b'delivers_good': 11,
#              b'good_lot': 21,
#              b'blood': 1186,
#              b'lot_blood': 25,
#              b'gore': 1040,
#              b'blood_gore': 73,
#              b'beheading': 16,
#              b'gore_beheading': 1,
#              b'hair': 519,
#              b'beheading_hair': 1,
#              b'raising': 94,
#              b'hair_raising': 6,
#              b'chill': 130,
#              b'raising_chill': 1,
#              b'full': 1780,
#              b'chill_full': 1,
#              b'scare': 408,
#              b'full_scare': 1,
#              b'scare_sabretooths': 1,
#              b'appear': 619,
#              b'sabretooths_appear': 1,
#              b'mediocre': 365,
#              b'appear_mediocre': 1,
#              b'special': 2135,
#              b'mediocre_special': 3,
#              b'effect': 2837,
#              b'special_effect': 1151,
#              b'story': 13163,
#              b'effect_story': 12,
#              b'provides': 350,
#              b'story_provides': 4,
#              b'exciting': 515,
#              b'provides_exciting': 1,
#              b'stirring': 41,
#              b'exciting_stirring': 1,
#              b'entertainment': 887,
#              b'stirring_entertainment': 1,
#              b'result': 906,
#              b'entertainment_result': 1,
#              b'quite': 3738,
#              b'result_quite': 2,
#              b'quite_boring': 17,
#              b'boring_giant': 1,
#              b'majority': 238,
#              b'animal_majority': 1,
#              b'majority_made': 1,
#              b'computer': 534,
#              b'made_computer': 3,
#              b'generator': 12,
#              b'computer_generator': 1,
#              b'seem': 2175,
#              b'generator_seem': 1,
#              b'totally': 1307,
#              b'seem_totally': 5,
#              b'lousy': 220,
#              b'totally_lousy': 1,
#              b'middling': 11,
#              b'lousy_middling': 1,
#              b'performance': 4717,
#              b'middling_performance': 1,
#              b'performance_though': 14,
#              b'player': 586,
#              b'though_player': 1,
#              b'reacting': 21,
#              b'player_reacting': 1,
#              b'appropriately': 77,
#              b'reacting_appropriately': 1,
#              b'becoming': 348,
#              b'appropriately_becoming': 1,
#              b'food': 338,
#              b'becoming_food': 1,
#              b'actor': 6875,
#              b'food_actor': 2,
#              b'actor_give': 32,
#              b'vigorously': 9,
#              b'give_vigorously': 1,
#              b'physical': 307,
#              b'vigorously_physical': 1,
#              b'physical_performance': 3,
#              b'dodging': 14,
#              b'performance_dodging': 1,
#              b'beast': 205,
#              b'dodging_beast': 1,
#              b'running': 992,
#              b'beast_running': 1,
#              b'bound': 200,
#              b'running_bound': 1,
#              b'leap': 90,
#              b'bound_leap': 1,
#              b'dangling': 19,
#              b'leap_dangling': 1,
#              b'wall': 500,
#              b'dangling_wall': 1,
#              b'wall_pack': 1,
#              b'ridiculous': 964,
#              b'pack_ridiculous': 1,
#              b'final': 1335,
#              b'ridiculous_final': 1,
#              b'final_deadly': 1,
#              b'deadly_scene': 1,
#              b'small': 1647,
#              b'scene_small': 5,
#              b'small_kid': 11,
#              b'realistic': 757,
#              b'kid_realistic': 1,
#              b'gory': 234,
#              b'realistic_gory': 3,
#              b'violent': 523,
#              b'gory_violent': 3,
#              b'attack': 606,
#              b'violent_attack': 1,
#              b'attack_scene': 16,
#              b'scene_film': 182,
#              b'film_sabretooths': 1,
#              b'sabretooths_smilodon': 1,
#              b'following': 565,
#              b'smilodon_following': 1,
#              b'following_sabretooth': 1,
#              b'james': 1069,
#              b'sabretooth_james': 1,
#              b'hickox': 7,
#              b'james_hickox': 2,
#              b'vanessa': 67,
#              b'hickox_vanessa': 1,
#              b'angel': 390,
#              b'vanessa_angel': 1,
#              b'david': 1025,
#              b'angel_david': 1,
#              b'keith': 88,
#              b'david_keith': 5,
#              b'john': 2222,
#              b'keith_john': 1,
#              b'rhys': 34,
#              b'john_rhys': 11,
#              b'davy': 140,
#              b'rhys_davy': 11,
#              b'much': 9763,
#              b'davy_much': 1,
#              b'better': 5739,
#              b'much_better': 746,
#              b'bc': 18,
#              b'better_bc': 1,
#              b'roland': 26,
#              b'bc_roland': 1,
#              b'emmerich': 4,
#              b'roland_emmerich': 3,
#              b'steven': 241,
#              b'emmerich_steven': 1,
#              b'strait': 20,
#              b'steven_strait': 1,
#              b'cliff': 127,
#              b'strait_cliff': 1,
#              b'curtis': 143,
#              b'cliff_curtis': 1,
#              b'camilla': 12,
#              b'curtis_camilla': 1,
#              b'belle': 50,
#              b'camilla_belle': 2,
#              b'motion': 501,
#              b'belle_motion': 1,
#              b'picture': 1937,
#              b'motion_picture': 168,
#              b'filled': 551,
#              b'picture_filled': 1,
#              b'bloody': 302,
#              b'filled_bloody': 1,
#              b'bloody_moment': 2,
#              b'badly': 662,
#              b'moment_badly': 1,
#              b'directed': 1204,
#              b'badly_directed': 16,
#              b'george': 929,
#              b'directed_george': 10,
#              b'miller': 170,
#              b'george_miller': 1,
#              b'originality': 171,
#              b'miller_originality': 1,
#              b'take': 5699,
#              b'originality_take': 1,
#              b'many': 6675,
#              b'take_many': 26,
#              b'element': 1175,
#              b'many_element': 27,
#              b'previous': 630,
#              b'element_previous': 2,
#              b'previous_film': 95,
#              b'film_miller': 1,
#              b'australian': 223,
#              b'miller_australian': 1,
#              b'australian_director': 1,
#              b'director_usually': 5,
#              b'usually_working': 1,
#              b'television': 909,
#              b'working_television': 2,
#              b'tidal': 6,
#              b'television_tidal': 1,
#              b'wave': 266,
#              b'tidal_wave': 6,
#              b'journey': 457,
#              b'wave_journey': 1,
#              b'journey_center': 8,
#              b'earth': 929,
#              b'center_earth': 11,
#              b'earth_many': 2,
#              b'many_others': 110,
#              b'occasionally': 256,
#              b'others_occasionally': 1,
#              b'occasionally_cinema': 1,
#              b'man': 6016,
#              b'cinema_man': 1,
#              b'snowy': 37,
#              b'man_snowy': 13,
#              b'river': 344,
#              b'snowy_river': 15,
#              b'zeus': 6,
#              b'river_zeus': 1,
#              b'roxanne': 6,
#              b'zeus_roxanne': 1,
#              b'robinson': 102,
#              b'roxanne_robinson': 1,
#              b'crusoe': 3,
#              b'robinson_crusoe': 2,
#              b'rating': 1094,
#              b'crusoe_rating': 1,
#              b'average': 723,
#              b'rating_average': 3,
#              b'average_bottom': 1,
#              b'barrel': 85,
#              b'bottom_barrel': 41,
#              b'barrel_': 4,
#              b'assumed': 82,
#              b'must_assumed': 1,
#              b'praised': 72,
#              b'assumed_praised': 1,
#              b'praised_film': 6,
#              b'greatest': 745,
#              b'film_greatest': 20,
#              b'filmed': 763,
#              b'greatest_filmed': 1,
#              b'opera': 428,
#              b'filmed_opera': 3,
#              b'opera_ever': 5,
#              b'read': 2057,
#              b'ever_read': 28,
#              b'somewhere': 482,
#              b'read_somewhere': 19,
#              b'somewhere_either': 1,
#              b'care': 1613,
#              b'either_care': 4,
#              b'care_opera': 1,
#              b'opera_care': 1,
#              b'wagner': 77,
#              b'care_wagner': 1,
#              b'wagner_care': 1,
#              b'anything': 2948,
#              b'care_anything': 9,
#              b'except': 1129,
#              b'anything_except': 24,
#              b'desire': 382,
#              b'except_desire': 2,
#              b'desire_appear': 1,
#              b'cultured': 15,
#              b'appear_cultured': 1,
#              b'cultured_either': 1,
#              b'representation': 80,
#              b'either_representation': 1,
#              b'representation_wagner': 1,
#              b'swan': 17,
#              b'wagner_swan': 1,
#              b'song': 1916,
#              b'swan_song': 7,
#              b'song_movie': 51,
#              b'strike': 266,
#              b'movie_strike': 4,
#              b'unmitigated': 9,
#              b'strike_unmitigated': 1,
#              b'disaster': 356,
#              b'unmitigated_disaster': 1,
#              b'leaden': 20,
#              b'disaster_leaden': 1,
#              b'reading': 703,
#              b'leaden_reading': 1,
#              b'score': 1121,
#              b'reading_score': 1,
#              b'matched': 89,
#              b'score_matched': 1,
#              b'tricksy': 2,
#              b'matched_tricksy': 1,
#              b'lugubrious': 5,
#              b'tricksy_lugubrious': 1,
#              b'realisation': 13,
#              b'lugubrious_realisation': 1,
#              b'text': 172,
#              b'realisation_text': 1,
#              b'questionable': 91,
#              b'text_questionable': 1,
#              b'questionable_people': 1,
#              b'idea': 2638,
#              b'people_idea': 10,
#              b'idea_opera': 1,
#              b'matter': 1351,
#              ...})

# %%
print(bigrams['space station near the solar system new york'.split()])
# Out:
# ['space_station', 'near', 'the', 'solar', 'system', 'new_york']

# %%
trigrams = Phrases(sentences=bigrams[corpus_train])

# %%
trigrams['space station near the solar system new york'.split()]
# Out:
# ['space_station', 'near', 'the', 'solar', 'system', 'new_york']

# %% [markdown]
# ---

# %%
print('Convert sentences to sentences with ngrams...', end='\r')
sents = trigrams[bigrams[corpus_train]]
print('Convert sentences to sentences with ngrams... (done)')
# Out:
# Convert sentences to sentences with ngrams... (done)

# %%
embedding_vector_size = 256
trigrams_model = Word2Vec(
    sentences = sents,
    size = embedding_vector_size,
    min_count=3, window=5, workers=4)

# %%
trigrams_model.wv.similar_by_word('great')
# Out:
# [('wonderful', 0.8543416261672974),
#  ('amazing', 0.8235388398170471),
#  ('excellent', 0.8076362609863281),
#  ('fantastic', 0.7923934459686279),
#  ('perfect', 0.767772376537323),
#  ('fine', 0.7621510624885559),
#  ('incredible', 0.7287273406982422),
#  ('brilliant', 0.7267520427703857),
#  ('awesome', 0.7170404195785522),
#  ('outstanding', 0.7048456072807312)]

# %%
# %%time
def vectorize_data(data, vocab: dict) -> list:
    print('Vectorize sentences...', end='\r')
    keys = list(vocab.keys())
    filter_unknown = lambda word: vocab.get(word, None) is not None
    encode = lambda review: list(map(keys.index, filter(filter_unknown, review)))
    vectorized = list(map(encode, data))
    print('Vectorize sentences... (done)')
    return vectorized
# Out:
# Wall time: 0 ns

# %%
vocab = trigrams_model.wv.vocab
keys = list(vocab.keys())
filter_unknown = lambda word: vocab.get(word, None) is not None
encode = lambda review: list(map(keys.index, filter(filter_unknown, review)))
list(map(encode, ['stuff', 'going', 'moment', 'mj', 'started', 'listening', 'music', 'watching', 'odd', 'documentary']))
# list(map(encode, ['stuff', 'going', 'moment']))
# Out:
# [[11065, 22428, 714, 14334, 14334],
#  [170, 13654, 170],
#  [4738, 4738, 3933, 13654, 22428],
#  [4738, 6469],
#  [11065, 22428, 4150, 22428, 3933, 21851],
#  [7511, 11065, 22428, 3933, 13654, 13654, 170],
#  [4738, 714, 11065, 8258],
#  [3683, 22428, 8258, 17387, 13654, 170],
#  [21851, 21851],
#  [21851, 8258, 714, 4738, 3933, 13654, 22428, 4150, 12102]]

# %%
x = vocab.get('stuff', None)
x

# %%
list(map(keys.index,'stuff'))
# Out:
# [11065, 22428, 714, 14334, 14334]

# %%
sentence = vectorize_data(sents, vocab=trigrams_model.wv.vocab)
# Out:
# Vectorize sentences... (done)

# %%
X_pad = pad_sequences(
    sequences=sentence,
    maxlen=150,
    padding='post')
print('Transform sentences to sequences... (done)')

# %% [markdown]
# ---

# %%
# %%time
def vectorize_data(data, vocab: dict) -> list:
    print('Vectorize sentences...', end='\r')
    keys = list(vocab.keys())
    filter_unknown = lambda word: vocab.get(word, None) is not None
    encode = lambda review: list(map(keys.index, filter(filter_unknown, review)))
    vectorized = list(map(encode, data))
    print('Vectorize sentences... (done)')
    return vectorized

print('Convert sentences to sentences with ngrams...', end='\r')
X_data = trigrams[bigrams[X_train_data]]
print('Convert sentences to sentences with ngrams... (done)')
input_length = 150
X_pad = pad_sequences(
    sequences=vectorize_data(X_data, vocab=trigrams_model.wv.vocab),
    maxlen=input_length,
    padding='post')
print('Transform sentences to sequences... (done)')
